# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
% matplotlib inline

from api_keys import api_key

from citipy import citipy

# %%
# generate the random lat and long values
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)

# %%
city_list = []

for i in range(len(lat)):
    # get the city name given the latitude and longitude
    city = citipy.nearest_city(lat[i], lng[i]).city_name
    
    # check city name if it is in our list
    if city not in city_list:
        # store the city name into a list
        city_list.append(city)

# %%
len(city_list)
# Out:
# 607

# %%
# a set is a list of only unique values
unique_cities = len(list(set(city_list)))

# %% [markdown]
# ## Perform the API Calls
# * get the API key and form request for weather

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# create empty list to store API call data
city_data = []

for i in range(len(city_list)):
    # try, except is used for error handling
    try:
        print("currently requesting city: ", city_list[i])
        # perform the API call and parse the data
        city_weather = requests.get(url + '&q=' + city_list[i]).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_temp = city_weather["main"]["temp_max"]
        city_name = city_weather["name"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        #'clouds': {'all': 75}
        #'wind': {'speed': 6.93, 'deg': 210},
        
        # save data to our list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_temp,
                          "Humidity": city_humidity,
                          "Clouds": city_clouds,
                          "Wind": city_wind})
    except:
        print("city not found, skipping...", city_list[i])
        # skips the current iteration
        pass
# Out:
# currently requesting city:  saint-pierre
# currently requesting city:  mataura
# currently requesting city:  necochea
# currently requesting city:  vao
# currently requesting city:  malanje
# currently requesting city:  isangel
# currently requesting city:  hithadhoo
# currently requesting city:  olinda
# currently requesting city:  punta arenas
# currently requesting city:  vaini
# currently requesting city:  rikitea
# currently requesting city:  kimbe
# currently requesting city:  abu dhabi
# currently requesting city:  bredasdorp
# currently requesting city:  vikindu
# currently requesting city:  hermanus
# currently requesting city:  saleaula
# city not found, skipping... saleaula
# currently requesting city:  san andres
# currently requesting city:  ushuaia
# currently requesting city:  albany
# currently requesting city:  manzhouli
# currently requesting city:  apatou
# currently requesting city:  oxford
# currently requesting city:  nueva loja
# currently requesting city:  bani
# currently requesting city:  camocim
# currently requesting city:  busselton
# currently requesting city:  cape town
# currently requesting city:  kyzyl
# currently requesting city:  biu
# currently requesting city:  port alfred
# currently requesting city:  mahebourg
# currently requesting city:  tasiilaq
# currently requesting city:  ilulissat
# currently requesting city:  thompson
# currently requesting city:  kavieng
# currently requesting city:  moses lake
# currently requesting city:  kapaa
# currently requesting city:  sicamous
# currently requesting city:  tecpan
# currently requesting city:  hilo
# currently requesting city:  virginia beach
# currently requesting city:  tumannyy
# city not found, skipping... tumannyy
# currently requesting city:  butaritari
# currently requesting city:  bluff
# currently requesting city:  atuona
# currently requesting city:  taolanaro
# city not found, skipping... taolanaro
# currently requesting city:  asosa
# currently requesting city:  jacqueville
# currently requesting city:  arraial do cabo
# currently requesting city:  te anau
# currently requesting city:  saint-augustin
# currently requesting city:  olafsvik
# city not found, skipping... olafsvik
# currently requesting city:  snasa
# currently requesting city:  araouane
# currently requesting city:  gat
# currently requesting city:  ampanihy
# currently requesting city:  mattru
# currently requesting city:  calama
# currently requesting city:  storforshei
# currently requesting city:  khatanga
# currently requesting city:  mahon
# currently requesting city:  alofi
# currently requesting city:  russell
# currently requesting city:  grand river south east
# city not found, skipping... grand river south east
# currently requesting city:  victoria
# currently requesting city:  carbondale
# currently requesting city:  leningradskiy
# currently requesting city:  severo-kurilsk
# currently requesting city:  georgetown
# currently requesting city:  san jose de rio tinto
# currently requesting city:  ponta delgada
# currently requesting city:  bardiyah
# city not found, skipping... bardiyah
# currently requesting city:  karanja
# currently requesting city:  mahanoro
# currently requesting city:  palabuhanratu
# city not found, skipping... palabuhanratu
# currently requesting city:  edd
# currently requesting city:  tiksi
# currently requesting city:  puerto ayora
# currently requesting city:  sept-iles
# currently requesting city:  saint-philippe
# currently requesting city:  raudeberg
# currently requesting city:  karaul
# city not found, skipping... karaul
# currently requesting city:  mantua
# currently requesting city:  port elizabeth
# currently requesting city:  barrow
# currently requesting city:  coquimbo
# currently requesting city:  san patricio
# currently requesting city:  jishou
# currently requesting city:  tha chang
# currently requesting city:  brae
# currently requesting city:  bambous virieux
# currently requesting city:  vostok
# currently requesting city:  fortuna
# currently requesting city:  norman wells
# currently requesting city:  lima
# currently requesting city:  razole
# currently requesting city:  maryborough
# currently requesting city:  dikson
# currently requesting city:  superior
# currently requesting city:  jabiru
# city not found, skipping... jabiru
# currently requesting city:  san francisco
# currently requesting city:  hamilton
# currently requesting city:  pisco
# currently requesting city:  attawapiskat
# city not found, skipping... attawapiskat
# currently requesting city:  bandarbeyla
# currently requesting city:  hobart
# currently requesting city:  bairiki
# city not found, skipping... bairiki
# currently requesting city:  amot
# currently requesting city:  adony
# currently requesting city:  yeppoon
# currently requesting city:  dingle
# currently requesting city:  mar del plata
# currently requesting city:  nikolskoye
# currently requesting city:  le port
# currently requesting city:  port harcourt
# currently requesting city:  bajo baudo
# city not found, skipping... bajo baudo
# currently requesting city:  sembakung
# currently requesting city:  chokurdakh
# currently requesting city:  kimovsk
# currently requesting city:  arona
# currently requesting city:  sayyan
# currently requesting city:  paamiut
# currently requesting city:  jamestown
# currently requesting city:  samarai
# currently requesting city:  mehamn
# currently requesting city:  yellowknife
# currently requesting city:  fort abbas
# currently requesting city:  atambua
# currently requesting city:  cabo san lucas
# currently requesting city:  amazar
# currently requesting city:  naze
# currently requesting city:  kyra
# city not found, skipping... kyra
# currently requesting city:  ariquemes
# currently requesting city:  dakar
# currently requesting city:  pilar
# currently requesting city:  novyy buyan
# currently requesting city:  bengkulu
# city not found, skipping... bengkulu
# currently requesting city:  carnarvon
# currently requesting city:  chambas
# currently requesting city:  yar-sale
# currently requesting city:  clyde river
# currently requesting city:  rocha
# currently requesting city:  saint anthony
# currently requesting city:  margate
# currently requesting city:  seymchan
# currently requesting city:  oparino
# currently requesting city:  maumere
# currently requesting city:  souillac
# currently requesting city:  aksu
# currently requesting city:  tuktoyaktuk
# currently requesting city:  nizhneyansk
# city not found, skipping... nizhneyansk
# currently requesting city:  kruisfontein
# currently requesting city:  sorland
# currently requesting city:  wilmington island
# currently requesting city:  karauzyak
# city not found, skipping... karauzyak
# currently requesting city:  nantucket
# currently requesting city:  belaya gora
# currently requesting city:  okhotsk
# currently requesting city:  flinders
# currently requesting city:  turukhansk
# currently requesting city:  yumen
# currently requesting city:  fort frances
# currently requesting city:  kadykchan
# city not found, skipping... kadykchan
# currently requesting city:  coihaique
# currently requesting city:  belushya guba
# city not found, skipping... belushya guba
# currently requesting city:  laguna
# currently requesting city:  vila
# currently requesting city:  avarua
# currently requesting city:  aklavik
# currently requesting city:  dawlatabad
# currently requesting city:  broken hill
# currently requesting city:  nampula
# currently requesting city:  ishinomaki
# currently requesting city:  lebu
# currently requesting city:  rusape
# currently requesting city:  maragogi
# currently requesting city:  chicama
# currently requesting city:  kahului
# currently requesting city:  dawei
# currently requesting city:  chuy
# currently requesting city:  samalaeulu
# city not found, skipping... samalaeulu
# currently requesting city:  tottori
# currently requesting city:  udachnyy
# currently requesting city:  mana
# currently requesting city:  alihe
# currently requesting city:  volot
# currently requesting city:  ribeira grande
# currently requesting city:  klaksvik
# currently requesting city:  umzimvubu
# city not found, skipping... umzimvubu
# currently requesting city:  ornskoldsvik
# currently requesting city:  ponta do sol
# currently requesting city:  henties bay
# currently requesting city:  ulundi
# currently requesting city:  morant bay
# currently requesting city:  goderich
# currently requesting city:  samusu
# city not found, skipping... samusu
# currently requesting city:  torbay
# currently requesting city:  nouadhibou
# currently requesting city:  esso
# currently requesting city:  dolbeau
# city not found, skipping... dolbeau
# currently requesting city:  weston
# currently requesting city:  saint george
# currently requesting city:  pevek
# currently requesting city:  ishigaki
# currently requesting city:  namibe
# currently requesting city:  vanimo
# currently requesting city:  longyearbyen
# currently requesting city:  kibiti
# currently requesting city:  vardo
# currently requesting city:  majene
# currently requesting city:  pyaozerskiy
# currently requesting city:  upernavik
# currently requesting city:  kudahuvadhoo
# currently requesting city:  young
# currently requesting city:  nahavand
# currently requesting city:  castro
# currently requesting city:  saskylakh
# currently requesting city:  guerrero negro
# currently requesting city:  lompoc
# currently requesting city:  canto do buriti
# currently requesting city:  new norfolk
# currently requesting city:  soe
# currently requesting city:  bluefield
# currently requesting city:  lagoa
# currently requesting city:  grindavik
# currently requesting city:  sobolevo
# currently requesting city:  kaitangata
# currently requesting city:  ormara
# currently requesting city:  christchurch
# currently requesting city:  cumberland
# currently requesting city:  codrington
# currently requesting city:  sentyabrskiy
# city not found, skipping... sentyabrskiy
# currently requesting city:  mrirt
# city not found, skipping... mrirt
# currently requesting city:  college
# currently requesting city:  ahipara
# currently requesting city:  kartaly
# currently requesting city:  vaitupu
# city not found, skipping... vaitupu
# currently requesting city:  kedougou
# currently requesting city:  gizo
# currently requesting city:  touros
# currently requesting city:  tsihombe
# city not found, skipping... tsihombe
# currently requesting city:  skierniewice
# currently requesting city:  kailua
# currently requesting city:  kargasok
# currently requesting city:  halalo
# city not found, skipping... halalo
# currently requesting city:  motril
# currently requesting city:  seoul
# currently requesting city:  rio grande
# currently requesting city:  mount isa
# currently requesting city:  acari
# currently requesting city:  abu samrah
# currently requesting city:  port-cartier
# currently requesting city:  esperance
# currently requesting city:  siilinjarvi
# currently requesting city:  yabelo
# currently requesting city:  kota bahru
# city not found, skipping... kota bahru
# currently requesting city:  beckley
# currently requesting city:  korsor
# currently requesting city:  bethel
# currently requesting city:  illoqqortoormiut
# city not found, skipping... illoqqortoormiut
# currently requesting city:  el monte
# currently requesting city:  sapao
# city not found, skipping... sapao
# currently requesting city:  inhambane
# currently requesting city:  bambanglipuro
# currently requesting city:  provideniya
# currently requesting city:  auki
# currently requesting city:  tura
# currently requesting city:  cherskiy
# currently requesting city:  mys shmidta
# city not found, skipping... mys shmidta
# currently requesting city:  luderitz
# currently requesting city:  kodiak
# currently requesting city:  san martin
# currently requesting city:  gornopravdinsk
# currently requesting city:  macusani
# currently requesting city:  sinnai
# currently requesting city:  nan
# currently requesting city:  karpuninskiy
# city not found, skipping... karpuninskiy
# currently requesting city:  evensk
# currently requesting city:  butia
# currently requesting city:  ucluelet
# currently requesting city:  tshela
# currently requesting city:  nishihara
# currently requesting city:  ancud
# currently requesting city:  quatre cocos
# currently requesting city:  athens
# currently requesting city:  gambo
# currently requesting city:  asau
# city not found, skipping... asau
# currently requesting city:  khani
# currently requesting city:  karasburg
# currently requesting city:  savannah bight
# currently requesting city:  bonavista
# currently requesting city:  taonan
# currently requesting city:  mahibadhoo
# currently requesting city:  lorengau
# currently requesting city:  bauchi
# currently requesting city:  viedma
# currently requesting city:  veraval
# currently requesting city:  chumikan
# currently requesting city:  sorong
# currently requesting city:  mentougou
# currently requesting city:  hinche
# currently requesting city:  constitucion
# currently requesting city:  coahuayana
# currently requesting city:  coos bay
# currently requesting city:  valleyview
# currently requesting city:  saint-joseph
# currently requesting city:  alice springs
# currently requesting city:  pangkalanbuun
# currently requesting city:  ondorhaan
# city not found, skipping... ondorhaan
# currently requesting city:  yulara
# currently requesting city:  barentsburg
# city not found, skipping... barentsburg
# currently requesting city:  kamenskoye
# city not found, skipping... kamenskoye
# currently requesting city:  kirakira
# currently requesting city:  tocopilla
# currently requesting city:  dmitrov
# currently requesting city:  freeport
# currently requesting city:  vredendal
# currently requesting city:  kutum
# currently requesting city:  vacaria
# currently requesting city:  thunder bay
# currently requesting city:  vetovo
# currently requesting city:  amderma
# city not found, skipping... amderma
# currently requesting city:  namatanai
# currently requesting city:  altamira
# currently requesting city:  charters towers
# currently requesting city:  meulaboh
# currently requesting city:  east london
# currently requesting city:  meadow lake
# currently requesting city:  praia da vitoria
# currently requesting city:  miles city
# currently requesting city:  sao miguel do araguaia
# currently requesting city:  sorvag
# city not found, skipping... sorvag
# currently requesting city:  shambu
# currently requesting city:  leh
# currently requesting city:  delfzijl
# currently requesting city:  santo amaro da imperatriz
# currently requesting city:  sakakah
# city not found, skipping... sakakah
# currently requesting city:  goba
# currently requesting city:  anchorage
# currently requesting city:  coroico
# currently requesting city:  sanghar
# currently requesting city:  kuah
# city not found, skipping... kuah
# currently requesting city:  vertientes
# currently requesting city:  banaue
# currently requesting city:  ust-kuyga
# currently requesting city:  sinjai
# currently requesting city:  tabialan
# city not found, skipping... tabialan
# currently requesting city:  umm kaddadah
# currently requesting city:  san cristobal
# currently requesting city:  labuhan
# currently requesting city:  yenagoa
# currently requesting city:  agirish
# currently requesting city:  kandalaksha
# currently requesting city:  cotonou
# currently requesting city:  ambulu
# currently requesting city:  andilamena
# currently requesting city:  yialos
# city not found, skipping... yialos
# currently requesting city:  saldanha
# currently requesting city:  wanning
# currently requesting city:  abtenau
# currently requesting city:  ostrovnoy
# currently requesting city:  harper
# currently requesting city:  soimi
# currently requesting city:  tevriz
# currently requesting city:  grand gaube
# currently requesting city:  zhuhai
# currently requesting city:  solovetskiy
# city not found, skipping... solovetskiy
# currently requesting city:  broome
# currently requesting city:  swift current
# currently requesting city:  asfi
# city not found, skipping... asfi
# currently requesting city:  saint-georges
# currently requesting city:  port hardy
# currently requesting city:  san pedro
# currently requesting city:  ust-tsilma
# currently requesting city:  fukue
# currently requesting city:  odweyne
# city not found, skipping... odweyne
# currently requesting city:  sitka
# currently requesting city:  la tuque
# currently requesting city:  mabaruma
# currently requesting city:  tasbuget
# city not found, skipping... tasbuget
# currently requesting city:  urumqi
# city not found, skipping... urumqi
# currently requesting city:  lucapa
# currently requesting city:  qasigiannguit
# currently requesting city:  kulhudhuffushi
# currently requesting city:  ruatoria
# city not found, skipping... ruatoria
# currently requesting city:  banyo
# currently requesting city:  camacha
# currently requesting city:  dunedin
# currently requesting city:  okha
# currently requesting city:  tual
# currently requesting city:  katsuura
# currently requesting city:  pyay
# currently requesting city:  kidal
# currently requesting city:  armacao dos buzios
# city not found, skipping... armacao dos buzios
# currently requesting city:  sehithwa
# currently requesting city:  cap malheureux
# currently requesting city:  kavaratti
# currently requesting city:  burgeo
# currently requesting city:  qaanaaq
# currently requesting city:  shelburne
# currently requesting city:  portland
# currently requesting city:  rawson
# currently requesting city:  axim
# currently requesting city:  jabinyanah
# currently requesting city:  sabya
# currently requesting city:  hualmay
# currently requesting city:  bababe
# city not found, skipping... bababe
# currently requesting city:  isla vista
# currently requesting city:  kieta
# currently requesting city:  longlac
# city not found, skipping... longlac
# currently requesting city:  eydhafushi
# currently requesting city:  omboue
# currently requesting city:  vestmanna
# currently requesting city:  oksfjord
# currently requesting city:  korla
# city not found, skipping... korla
# currently requesting city:  el limon
# currently requesting city:  falun
# currently requesting city:  brahmapuri
# city not found, skipping... brahmapuri
# currently requesting city:  san quintin
# currently requesting city:  lolua
# city not found, skipping... lolua
# currently requesting city:  berlevag
# currently requesting city:  log
# currently requesting city:  salinopolis
# currently requesting city:  geraldton
# currently requesting city:  rafaela
# currently requesting city:  geresk
# city not found, skipping... geresk
# currently requesting city:  mayo
# currently requesting city:  darnah
# currently requesting city:  walvis bay
# currently requesting city:  curaca
# currently requesting city:  zabid
# currently requesting city:  los llanos de aridane
# currently requesting city:  turbat
# currently requesting city:  akyab
# city not found, skipping... akyab
# currently requesting city:  odienne
# currently requesting city:  black river
# currently requesting city:  port hedland
# currently requesting city:  yekepa
# currently requesting city:  bocana de paiwas
# currently requesting city:  hobyo
# currently requesting city:  deputatskiy
# currently requesting city:  aswan
# currently requesting city:  cockburn town
# currently requesting city:  namtsy
# currently requesting city:  kaeo
# currently requesting city:  satitoa
# city not found, skipping... satitoa
# currently requesting city:  north bend
# currently requesting city:  havoysund
# currently requesting city:  dhola
# currently requesting city:  craig
# currently requesting city:  airai
# currently requesting city:  taksimo
# currently requesting city:  taormina
# currently requesting city:  cidreira
# currently requesting city:  vigrestad
# currently requesting city:  camopi
# currently requesting city:  aktash
# city not found, skipping... aktash
# currently requesting city:  hovd
# currently requesting city:  palora
# currently requesting city:  kemin
# currently requesting city:  zhenlai
# currently requesting city:  port keats
# currently requesting city:  gamba
# currently requesting city:  makung
# city not found, skipping... makung
# currently requesting city:  kampene
# currently requesting city:  sai buri
# currently requesting city:  mocuba
# currently requesting city:  kinsale
# currently requesting city:  perivolion
# currently requesting city:  pervoye maya
# currently requesting city:  gulshat
# city not found, skipping... gulshat
# currently requesting city:  teruel
# currently requesting city:  villa bruzual
# currently requesting city:  tiarei
# currently requesting city:  kosonsoy
# currently requesting city:  ust-nera
# currently requesting city:  ketchenery
# city not found, skipping... ketchenery
# currently requesting city:  ambilobe
# currently requesting city:  awjilah
# currently requesting city:  novomoskovsk
# currently requesting city:  natal
# currently requesting city:  kermanshah
# currently requesting city:  tabiauea
# city not found, skipping... tabiauea
# currently requesting city:  forestville
# currently requesting city:  byron bay
# currently requesting city:  vuktyl
# currently requesting city:  hami
# currently requesting city:  humberto de campos
# currently requesting city:  torgelow
# currently requesting city:  urubicha
# currently requesting city:  griffith
# currently requesting city:  kloulklubed
# currently requesting city:  gonbad-e qabus
# currently requesting city:  ambodifototra
# city not found, skipping... ambodifototra
# currently requesting city:  talnakh
# currently requesting city:  lengshuitan
# currently requesting city:  whitehorse
# currently requesting city:  nanortalik
# currently requesting city:  robertsport
# currently requesting city:  caramay
# currently requesting city:  kununurra
# currently requesting city:  pilot butte
# currently requesting city:  jiddah
# city not found, skipping... jiddah
# currently requesting city:  uruacu
# currently requesting city:  peniche
# currently requesting city:  nabire
# currently requesting city:  luanda
# currently requesting city:  devonport
# currently requesting city:  maceio
# currently requesting city:  tukrah
# city not found, skipping... tukrah
# currently requesting city:  anloga
# currently requesting city:  tiznit
# currently requesting city:  calvia
# currently requesting city:  nome
# currently requesting city:  gorin
# currently requesting city:  powell river
# currently requesting city:  kokoda
# currently requesting city:  newton
# currently requesting city:  qurayyat
# city not found, skipping... qurayyat
# currently requesting city:  sechura
# currently requesting city:  azimur
# city not found, skipping... azimur
# currently requesting city:  bathsheba
# currently requesting city:  cozumel
# city not found, skipping... cozumel
# currently requesting city:  itaituba
# currently requesting city:  colares
# currently requesting city:  port-gentil
# currently requesting city:  mango
# currently requesting city:  ishurdi
# currently requesting city:  pavlivka
# currently requesting city:  aljezur
# currently requesting city:  pontianak
# currently requesting city:  tabuk
# currently requesting city:  grafton
# currently requesting city:  mazamari
# currently requesting city:  lasa
# currently requesting city:  coxim
# currently requesting city:  biak
# currently requesting city:  xuanhua
# currently requesting city:  kuressaare
# currently requesting city:  nanyang
# currently requesting city:  dudinka
# currently requesting city:  phonhong
# currently requesting city:  skagastrond
# city not found, skipping... skagastrond
# currently requesting city:  itarema
# currently requesting city:  grants pass
# currently requesting city:  emerald
# currently requesting city:  westport
# currently requesting city:  oytal
# currently requesting city:  reitz
# currently requesting city:  caravelas
# currently requesting city:  puntarenas
# currently requesting city:  tessalit
# currently requesting city:  kamenka
# currently requesting city:  paciran
# currently requesting city:  jacareacanga
# currently requesting city:  haines junction
# currently requesting city:  acapulco
# currently requesting city:  libreville
# currently requesting city:  husavik
# currently requesting city:  sinnamary
# currently requesting city:  jinchengjiang
# city not found, skipping... jinchengjiang
# currently requesting city:  maldonado
# currently requesting city:  enshi
# currently requesting city:  blahodatne
# currently requesting city:  saryshagan
# city not found, skipping... saryshagan
# currently requesting city:  mayumba
# currently requesting city:  padang
# currently requesting city:  kaabong
# currently requesting city:  longhua
# currently requesting city:  kankon
# currently requesting city:  matara
# currently requesting city:  mnogovershinnyy
# currently requesting city:  palmer
# currently requesting city:  mocambique
# city not found, skipping... mocambique
# currently requesting city:  sabang
# currently requesting city:  collierville
# currently requesting city:  talas
# currently requesting city:  mount gambier
# currently requesting city:  port blair
# currently requesting city:  kungurtug
# currently requesting city:  sibolga
# currently requesting city:  katobu
# currently requesting city:  xinyu
# currently requesting city:  machala
# currently requesting city:  waihi beach
# currently requesting city:  nioro
# currently requesting city:  toliary
# city not found, skipping... toliary
# currently requesting city:  guerrero
# currently requesting city:  ocean city
# currently requesting city:  san juan
# currently requesting city:  ottawa
# currently requesting city:  zachagansk
# city not found, skipping... zachagansk
# currently requesting city:  rio gallegos
# currently requesting city:  catuday
# currently requesting city:  luwuk
# currently requesting city:  salinas
# currently requesting city:  abnub
# currently requesting city:  foumban
# currently requesting city:  mikkeli
# currently requesting city:  marsh harbour
# currently requesting city:  maymyo
# currently requesting city:  mpanda
# currently requesting city:  carora
# currently requesting city:  palana
# currently requesting city:  chagda
# city not found, skipping... chagda
# currently requesting city:  hihifo
# city not found, skipping... hihifo

# %%
sample_call = requests.get(url + '&q=' + city_list[0]).json()

# %%
sample_call
# Out:
# {'coord': {'lon': 4.24, 'lat': 48.95},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 61.61,
#   'pressure': 1018,
#   'humidity': 82,
#   'temp_min': 60.8,
#   'temp_max': 62.6},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 360},
#  'clouds': {'all': 0},
#  'dt': 1534899600,
#  'sys': {'type': 1,
#   'id': 5604,
#   'message': 0.0201,
#   'country': 'FR',
#   'sunrise': 1534913114,
#   'sunset': 1534963538},
#  'id': 2995603,
#  'name': 'Saint-Pierre',
#  'cod': 200}

# %%
sample_call["coord"]["lat"]
# Out:
# 48.95

# %%
sample_call["main"]["temp_max"]
# Out:
# 62.6

# %%
sample_call["weather"][0]
# Out:
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}

# %% [markdown]
# ## Analysis
# * make dataframe
# * visualize the data
# * save the plots

# %%
len(city_data)
# Out:
# 531

# %%
# make the dataframe
df = pd.DataFrame(city_data)

# %%
df.head(531)
# Out:
#                 City  Clouds  Humidity    Lat     Lng  Max Temp   Wind
# 0       Saint-Pierre       0        82  48.95    4.24     62.60   5.82
# 1            Mataura      36        93 -46.19  168.86     48.22   4.50
# 2           Necochea       0        69 -38.55  -58.74     42.01  11.77
# 3                Vao       0        65  59.10   26.19     53.44  10.65
# 4            Malanje       0        94  -9.54   16.35     61.54   4.38
# 5            Isangel      36       100 -19.55  169.27     72.88  13.67
# 6          Hithadhoo     100       100  -0.60   73.08     79.90   5.95
# 7             Olinda       0        73  -2.03  -79.75     73.40  14.99
# 8       Punta Arenas      75        75 -53.16  -70.91     41.00   2.24
# 9              Vaini      92        98  15.34   74.49     70.00   7.63
# 10           Rikitea       0       100 -23.12 -134.97     70.81  13.56
# 11             Kimbe      88       100  -5.56  150.15     78.73   3.27
# 12         Abu Dhabi       0        75  24.47   54.37     91.40   4.70
# 13        Bredasdorp      44       100 -34.53   20.04     51.10  12.21
# 14           Vikindu      20        94  -6.98   39.30     69.80   2.71
# 15          Hermanus      12        95 -34.42   19.24     32.38   3.38
# 16        San Andres      12        93  13.32  122.68     84.49  21.83
# 17           Ushuaia      75        86 -54.81  -68.31     39.20   4.70
# 18            Albany      90        60  42.65  -73.75     75.20  10.29
# 19         Manzhouli       0        76  49.60  117.43     63.88   4.61
# 20            Apatou       0        77   5.16  -54.34     79.09   4.38
# 21            Oxford      40        61  33.61  -85.83     82.40   6.93
# 22        Nueva Loja      88        98   0.08  -76.88     70.81   2.37
# 23              Bani      92       100  15.89  120.27     74.32   8.19
# 24           Camocim       0        59  -2.90  -40.84     80.71  15.79
# 25         Busselton      44       100 -33.64  115.35     55.06  17.69
# 26         Cape Town      75        93 -33.93   18.42     42.80   3.36
# 27             Kyzyl     100        84  51.72   94.43     54.88   2.82
# 28               Biu      68        81  10.61   12.19     73.96   9.98
# 29       Port Alfred      68       100 -33.59   26.89     58.66   3.83
# ..               ...     ...       ...    ...     ...       ...    ...
# 501  Mnogovershinnyy      92        87  53.94  139.92     64.20   3.27
# 502           Palmer       0        23 -34.85  139.16     62.60  14.99
# 503           Sabang      24        73  13.72  123.58     87.96  17.69
# 504     Collierville      75        83  35.04  -89.66     78.80   4.70
# 505            Talas       0        58  38.69   35.55     59.00   2.24
# 506    Mount Gambier      12        88 -37.83  140.78     54.12   4.50
# 507       Port Blair      68       100  11.67   92.75     81.25  13.44
# 508        Kungurtug       8        67  50.60   97.53     63.30   3.38
# 509          Sibolga      64        83   1.74   98.78     77.25   2.37
# 510           Katobu      48        74  -4.94  122.53     85.98   5.17
# 511            Xinyu       8        65  27.80  114.93     91.38   6.85
# 512          Machala      20        83  -3.26  -79.96     69.80   5.82
# 513      Waihi Beach      88        98 -37.40  175.93     51.15   9.08
# 514            Nioro      32        85  13.79  -15.05     76.17   9.86
# 515         Guerrero      20        66 -24.19  -65.45     46.40   4.70
# 516       Ocean City      40        74  30.44  -86.61     84.20   9.17
# 517         San Juan       0        76 -31.54  -68.53     37.20   5.39
# 518           Ottawa      92        98  45.42  -75.69     66.63   7.18
# 519     Rio Gallegos       0        81 -51.62  -69.22     42.80   4.70
# 520          Catuday      92       100  16.29  119.81     77.97  15.01
# 521            Luwuk      48        91  -0.95  122.79     79.23   5.95
# 522          Salinas      75        64  36.67 -121.66     68.00  11.41
# 523            Abnub       0        48  27.27   31.15     82.40   9.17
# 524          Foumban      92       100   5.73   10.90     62.58   2.26
# 525          Mikkeli       0        76  61.69   27.27     48.20   5.82
# 526    Marsh Harbour      64       100  26.54  -77.06     83.46   9.08
# 527           Maymyo      90        94  22.03   96.47     78.80  10.29
# 528           Mpanda      80        60  -6.34   31.07     64.92   3.27
# 529           Carora       8        64  10.17  -70.08     76.98  14.67
# 530           Palana      76        65  59.08  159.95     54.48   5.73
#
# [531 rows x 7 columns]

# %%
df.to_csv('data.csv')

# %%
#Latitude vs Max Temp Scatter

plt.scatter(df["Lat"], df["Max Temp"])
plt.title("City Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')


plt.savefig("C:/Users/Sal/Desktop/Fig1.png")

# %%
plt.scatter(df["Lat"], df["Humidity"])
plt.title("City Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')


plt.savefig("C:/Users/Sal/Desktop/Fig2.png")

# %%
city_weather
# Out:
# {'coord': {'lon': -56.22, 'lat': -34.68},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 48.2,
#   'pressure': 1028,
#   'humidity': 76,
#   'temp_min': 48.2,
#   'temp_max': 48.2},
#  'visibility': 10000,
#  'wind': {'speed': 6.93, 'deg': 210},
#  'clouds': {'all': 75},
#  'dt': 1534827600,
#  'sys': {'type': 1,
#   'id': 4623,
#   'message': 0.0038,
#   'country': 'UY',
#   'sunrise': 1534846655,
#   'sunset': 1534886324},
#  'id': 3440963,
#  'name': 'Progreso',
#  'cod': 200}

# %%
plt.scatter(df["Lat"], df["Clouds"])
plt.title("City Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


plt.savefig("C:/Users/Sal/Desktop/Fig3.png")

# %%
plt.scatter(df["Lat"], df["Wind"])
plt.title("City Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')


plt.savefig("C:/Users/Sal/Desktop/Fig4.png")
